# %%
# %run Workspace/Users/georgiavieiras@gmail.com/Ecommerce/Conexão_Ambiente

# %%
# Lê a tabela 'produto' do schema 'public' via JDBC
df = spark.read.jdbc(
    url=jdbc_url,                    # URL de conexão JDBC
    table="public.produtos",          # Tabela específica
    properties=connection_properties # Credenciais e configurações
)

display(df)  # Exibe o DataFrame (Databricks/Jupyter)
