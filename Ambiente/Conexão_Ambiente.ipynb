# %%
#Variáveis
jdbc_hostname = "dpg-d5v5eg0gjchc7392svh0-a.oregon-postgres.render.com"
jdbc_port = "5432"
jdbc_database = "trilha_sql"
jdbc_username = "trilha_sql_user"
jdbc_password = "moorXRPu21Mzti8fEAsrx3rOKgzuzeEX"


# Construir URL de conexão
jdbc_url = f"jdbc:postgresql://{jdbc_hostname}:{jdbc_port}/{jdbc_database}"

# Propriedades de conexão
connection_properties = {
    "user": jdbc_username,
    "password": jdbc_password,
    "driver": "org.postgresql.Driver"
}

print("✅ Configuração carregada com sucesso!")

print(type(jdbc_url))
print(type(connection_properties))
