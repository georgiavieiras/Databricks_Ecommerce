# %%
# %sql

-- Criando CATALOG

CREATE CATALOG IF NOT EXISTS ecommerce COMMENT 'Catalog Ecommerce - Projeto ETL';

-- Criando SCHEMAS

CREATE SCHEMA IF NOT EXISTS ecommerce.bronze COMMENT 'Camada Bronze - Dados Raw';
CREATE SCHEMA IF NOT EXISTS ecommerce.silver COMMENT 'Camada Silver - Dados Processados';
CREATE SCHEMA IF NOT EXISTS ecommerce.gold COMMENT 'Camada Gold - Agregações';
